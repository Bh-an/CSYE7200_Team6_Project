# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import skimage.io as io

# %%
savepath = "../checkpoints"
files = os.listdir(savepath)
files
# Out:
# ['savelabels.npy', 'savepredictions.npy', 'logs', 'save']

# %%
lbls = np.load(os.path.join(savepath, files[0]))
preds = np.load(os.path.join(savepath, files[1]))

# %%
preds.shape
# Out:
# (4, 1, 480, 480)

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))
ax[0].imshow(preds[3][0])
ax[1].imshow(lbls[3][0])

# %%
io.imsave("src/main/resources/preds.png", preds[3][0])
io.imsave("src/main/resources/lbls.png", lbls[3][0])
# Out:
# /var/folders/rz/26nbj19s1_33yvwj408l10gr0000gn/T/ipykernel_49223/2922705614.py:1: UserWarning: preds.png is a low contrast image
#   io.imsave("preds.png", preds[3][0])
# Lossy conversion from int32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /var/folders/rz/26nbj19s1_33yvwj408l10gr0000gn/T/ipykernel_49223/2922705614.py:2: UserWarning: lbls.png is a low contrast image
#   io.imsave("lbls.png", lbls[3][0])

# %%
io.imshow(io.imread("src/main/resources/preds.png"))

# %%
io.imshow(io.imread("src/main/resources/lbls.png"))
# Out:
# /Users/nish/miniconda3/envs/detect/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
